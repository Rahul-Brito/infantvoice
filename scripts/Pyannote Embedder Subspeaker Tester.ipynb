# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
from random import seed, shuffle
import os
import glob as glob
from pathlib import Path
from datetime import datetime
import json

from pyannote.audio import Pipeline
from pyannote.core import json
from pyannote.core.timeline import Timeline

import moviepy.editor as mp

from matplotlib import pyplot as plt, lines
import seaborn as sns

from sklearn.cluster import KMeans, SpectralClustering
from sklearn.preprocessing import StandardScaler

from scipy import stats
from scipy.spatial.distance import directed_hausdorff, euclidean, cosine, pdist

from src import (
    downsample as downsamp_audio, 
    embedding_extractor as ee, 
    dimension_reducer as dr, 
    distance_metrics as dm, 
    downsample as ds,
    emb_manipulator as em
)

from IPython.display import clear_output
import warnings
warnings.filterwarnings('ignore')
# Out:
# OMP: Info #271: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
def extract_audio_from_video_and_return_path(root_dir):
    #takes in root directory
    #extracts audio from video and puts it in /audio
    #also returns the location of the audio (bad practice but works!)
    
    vid_files = glob.glob(root_dir + '/*', recursive=True)
    {Path(vid).stem:
               vid for vid in vid_files}

    my_clip = {Path(vid).stem:
               mp.VideoFileClip(vid) for vid in vid_files}

    aud_files = os.path.join(root_dir,'audio')

    if not os.path.exists(aud_files):
        os.mkdir(aud_files)

    [mov.audio.write_audiofile(os.path.join(aud_files,part + '.wav')) for part,mov in my_clip.items()]
    
    return aud_files

def extract_16khz_audio(root_dir, video=False):
    
    #outputs audio downsampled to 16khz, returns the path of the audio
    #if the input is video, will extract audio at 44khz first then downsample
    #otherwise will just downsample
    
    #if data is in video format, extract audio
    
    if video:
        aud_files = extract_audio_from_video_and_return_path(root_dir)
    else:
        aud_files = root_dir

    
    #downsample audio (either extracted from folder or given to me)
    
    #make a folder with today's date for the downsampled audio if it doesn't exist
    down_sample_dir = os.path.join(root_dir,"audio_16kz")
    if not os.path.exists(down_sample_dir):
        os.mkdir(down_sample_dir)
    
    ds.downsamp_audio(aud_files, down_sample_dir)
    
    return down_sample_dir

# %%
##Downsample audio to 16kHz
#root_dir= "/Users/rahulbrito/Documents/projects/infantvoice/data/Full_Readings/Noise_Reduced"
#root_dir='/Users/rahulbrito/Documents/projects/infantvoice/data/Full_Readings/Loudness_Test_8.9.22'
root_dir='/Users/rahulbrito/Documents/projects/infantvoice/data/Full_Readings/Noise_Reduced_1023'
# !ls $root_dir
# Out:
# BB036_BookReading_Reduced.wav BB046_BookReading_Reduced.wav
# BB041_BookReading_Reduced.wav BB047_BookReading_Reduced.wav
# BB043_BookReading_Reduced.wav BB051_BookReading_Reduced.wav

# %%
down_sample_dir = extract_16khz_audio(root_dir, video=False)
down_sample_dir
# Out:
# processingBB051_BookReading_Reduced.wav
# '/Users/rahulbrito/Documents/projects/infantvoice/data/Full_Readings/Noise_Reduced_1023/audio_16kz'

# %%
##Diarize audio to find when mother is speaking and visualize it to choose label

diar_dir = os.path.join(root_dir,'diarized')
  
if not os.path.exists(diar_dir):
    os.mkdir(diar_dir)

diar_dir
# Out:
# '/Users/rahulbrito/Documents/projects/infantvoice/data/Full_Readings/Noise_Reduced_1023/diarized'

# %%
## Runs speaker diariztion, but should run on openmind

#pipeline = Pipeline.from_pretrained("pyannote/speaker-diarization@2022.07")

#for file in os.listdir(down_sample_dir):
#    if file.endswith('wav'):
#        diar = pipeline(os.path.join(down_sample_dir,file))
#        json.dump_to(diar, os.path.join(diar_dir, os.path.splitext(file)[0]+'.json'))

# %%
diarized_raw = {os.path.splitext(file)[0]:
            json.load_from(os.path.join(diar_dir,file)) for file in os.listdir(diar_dir) if file != 'speaker_map.json'}
diarized_raw.keys()
# Out:
# dict_keys(['BB041_BookReading_Reduced', 'BB051_BookReading_Reduced', 'BB043_BookReading_Reduced', 'BB047_BookReading_Reduced', 'BB046_BookReading_Reduced', 'BB036_BookReading_Reduced'])

# %%
diarized_raw['BB041_BookReading_Reduced']

# %%
speaker_map = {'BB041_BookReading_Reduced':['SPEAKER_00'],
               'BB051_BookReading_Reduced':['SPEAKER_00', 'SPEAKER_01'],
               'BB043_BookReading_Reduced':['SPEAKER_00'],
               'BB047_BookReading_Reduced':['SPEAKER_00'],
               'BB046_BookReading_Reduced':['SPEAKER_00'],
               'BB036_BookReading_Reduced':['SPEAKER_00']
              }

# %%
[diarized_raw[s] for s in speaker_map.keys()]
# Out:
# [<pyannote.core.annotation.Annotation at 0x7ff581f6e4f0>,
#  <pyannote.core.annotation.Annotation at 0x7ff581f6e7c0>,
#  <pyannote.core.annotation.Annotation at 0x7ff5732aee80>,
#  <pyannote.core.annotation.Annotation at 0x7ff5624b3340>,
#  <pyannote.core.annotation.Annotation at 0x7ff5624cd760>,
#  <pyannote.core.annotation.Annotation at 0x7ff573278430>]

# %%
#speaker_map = {'BB040_BookReading_Reduced':['SPEAKER_01'],
#               'BB034_BookReading_Reduced':['SPEAKER_00'],
#               'BB031_BookReading_Reduced':['SPEAKER_00','SPEAKER_01'],
#               'BB037_BookReading_Reduced':['SPEAKER_01'],
#               'BB029_BookReading_Reduced':['SPEAKER_00'],
#               'BB032_BookReading_Reduced':['SPEAKER_00','SPEAKER_01','SPEAKER_02','SPEAKER_03']
#              }

# %%
speaker_map_json = '/Users/rahulbrito/Documents/projects/infantvoice/data/Full_Readings/Noise_Reduced/diarized/speaker_map.json'
with open(speaker_map_json) as json_file:
    speaker_map = json.load(json_file)
    
len(speaker_map.keys())
# Out:
# 35

# %%
speaker_map_df = pd.DataFrame(speaker_map.items(), columns=['part_id', 'pyannote_speakers'])
speaker_map_df = speaker_map_df.explode('pyannote_speakers').reset_index(drop=True)

# %%
[[diarized_raw[label].label_timeline(s) for s in speaker_map_df.pyannote_speakers] for label in speaker_map_df.part_id]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/fg/c6b2vcrx7wd1530hgxsj7z7w0000gn/T/ipykernel_1243/114093237.py in <module>
# ----> 1 [[diarized_raw[label].label_timeline(s) for s in speaker_map_df.pyannote_speakers] for label in speaker_map_df.part_id]
#
# /var/folders/fg/c6b2vcrx7wd1530hgxsj7z7w0000gn/T/ipykernel_1243/114093237.py in <listcomp>(.0)
# ----> 1 [[diarized_raw[label].label_timeline(s) for s in speaker_map_df.pyannote_speakers] for label in speaker_map_df.part_id]
#
# /var/folders/fg/c6b2vcrx7wd1530hgxsj7z7w0000gn/T/ipykernel_1243/114093237.py in <listcomp>(.0)
# ----> 1 [[diarized_raw[label].label_timeline(s) for s in speaker_map_df.pyannote_speakers] for label in speaker_map_df.part_id]
#
# KeyError: '011'

# %%
# Based on output of diarization, manually make speaker map to set which speaker we want
temp = {label:[diarized_raw[label].label_timeline(s) for s in s_list]
        for label,s_list in speaker_map.items()
        if label in diarized_raw.keys()
       }

diarized = {}

for label, all_timelines in temp.items():
    all_seg = Timeline()
    for timeline in all_timelines:
        all_seg = all_seg.union(timeline)
    
    diarized[label] = all_seg
    #add specific label modifiers given extra data labels (need a better way)
    #diarized[label + '_Quiet'] = all_seg
    #diarized[label + '_Loud'] = all_seg
    #if 'BB' in label:
    #    diarized[label + '_BookReading_Reduced'] = all_seg
    #else:
    #    diarized[label + '_Reduced'] = all_seg

# %%
diarized.keys()
# Out:
# dict_keys(['BB041_BookReading_Reduced', 'BB051_BookReading_Reduced', 'BB043_BookReading_Reduced', 'BB047_BookReading_Reduced', 'BB046_BookReading_Reduced', 'BB036_BookReading_Reduced'])

# %%
diarized['BB041_BookReading_Reduced']
# Out:
# <Timeline(uri=None, segments=[<Segment(0.497812, 1.29094)>, <Segment(3.36656, 4.41281)>, <Segment(5.27344, 7.55156)>, <Segment(9.39094, 10.2009)>, <Segment(10.3866, 11.5341)>, <Segment(12.7322, 15.3141)>, <Segment(16.7316, 17.7441)>, <Segment(18.3684, 19.6509)>, <Segment(21.5578, 22.6547)>, <Segment(23.1272, 24.1397)>, <Segment(28.6959, 30.0797)>, <Segment(30.4509, 31.8516)>, <Segment(33.4884, 34.6191)>, <Segment(34.8722, 36.2728)>, <Segment(38.7028, 39.7491)>, <Segment(40.9809, 42.0947)>, <Segment(43.4447, 45.3516)>, <Segment(45.8241, 46.9041)>, <Segment(49.8572, 51.2409)>, <Segment(51.8316, 52.8609)>, <Segment(54.1097, 56.2022)>, <Segment(61.0791, 63.4753)>, <Segment(63.6947, 65.6353)>, <Segment(66.2091, 68.5884)>, <Segment(69.0609, 70.3097)>, <Segment(70.7653, 73.9884)>, <Segment(74.4609, 75.6759)>, <Segment(77.1441, 80.4009)>, <Segment(80.9747, 82.6284)>, <Segment(82.9997, 84.7884)>, <Segment(85.3622, 87.1172)>, <Segment(91.2009, 93.1584)>, <Segment(93.7322, 96.1959)>, <Segment(96.7191, 98.4741)>, <Segment(98.9972, 101.562)>, <Segment(101.849, 103.587)>, <Segment(105.292, 106.49)>, <Segment(108.633, 109.831)>, <Segment(110.202, 113.678)>, <Segment(114.978, 118.083)>, <Segment(118.42, 120.8)>, <Segment(122.555, 125.002)>, <Segment(125.508, 126.757)>, <Segment(127.398, 129.203)>, <Segment(129.912, 133.372)>, <Segment(133.912, 135.937)>, <Segment(139.902, 143.378)>, <Segment(144.053, 147.327)>, <Segment(148.559, 150.23)>, <Segment(152.305, 154.803)>, <Segment(155.36, 156.895)>, <Segment(158.077, 160.625)>, <Segment(161.215, 161.654)>, <Segment(161.992, 163.223)>, <Segment(165.383, 168.033)>, <Segment(168.775, 170.21)>, <Segment(172.117, 174.783)>, <Segment(175.373, 176.909)>, <Segment(178.377, 181.027)>, <Segment(181.685, 182.798)>, <Segment(184.334, 187.034)>, <Segment(187.473, 188.722)>, <Segment(189.211, 190.173)>, <Segment(190.443, 192.265)>, <Segment(192.704, 194.105)>, <Segment(194.712, 195.792)>, <Segment(196.484, 198.037)>, <Segment(198.56, 199.808)>, <Segment(200.197, 201.074)>, <Segment(201.631, 203.251)>, <Segment(204.044, 205.917)>, <Segment(205.951, 205.968)>, <Segment(210.22, 212.718)>, <Segment(213.072, 216.43)>, <Segment(216.869, 219.94)>, <Segment(220.632, 222.708)>, <Segment(224.21, 227.821)>, <Segment(228.597, 230.993)>, <Segment(231.314, 233.66)>, <Segment(234.233, 236.663)>, <Segment(237.119, 239.077)>, <Segment(239.482, 239.954)>, <Segment(240.325, 240.747)>, <Segment(241.135, 243.515)>, <Segment(246.839, 248.797)>, <Segment(249.235, 251.362)>, <Segment(257.183, 259.343)>, <Segment(260.035, 262.111)>, <Segment(262.415, 263.647)>, <Segment(265.823, 268.709)>, <Segment(269.249, 270.852)>, <Segment(272.86, 277.433)>, <Segment(279.003, 280.977)>, <Segment(283.407, 286.023)>, <Segment(286.411, 287.086)>, <Segment(287.525, 289.718)>, <Segment(294.443, 295.372)>, <Segment(296.013, 298.021)>, <Segment(298.612, 299.658)>, <Segment(301.025, 303.607)>, <Segment(303.978, 305.277)>, <Segment(306.863, 308.483)>, <Segment(308.753, 310.88)>, <Segment(311.352, 313.968)>, <Segment(315.925, 317.444)>, <Segment(317.9, 320.296)>, <Segment(320.836, 324.059)>, <Segment(325.848, 327.434)>, <Segment(327.94, 330.539)>, <Segment(331.045, 332.48)>, <Segment(333.037, 334.522)>, <Segment(338.065, 341.845)>, <Segment(343.533, 345.912)>, <Segment(346.233, 349.439)>, <Segment(352.443, 355.868)>, <Segment(356.273, 359.429)>, <Segment(361.673, 364.829)>, <Segment(365.268, 368.221)>, <Segment(370.145, 371.14)>, <Segment(371.528, 373.621)>, <Segment(377.283, 377.958)>])>

# %%
emb_dir = '/Users/rahulbrito/Documents/projects/infantvoice/data/embeddings'
save_name = datetime.now().strftime('%Y_%m_%d') + '_noise_reduced.csv'
diarized = diarized

import glob
#all_files = glob.glob(down_sample_dir+'/*/*', recursive=True)
#all_files = [file for file in all_files if 'script' in file]

all_files = glob.glob(down_sample_dir+'/*', recursive=True)

save_name, all_files
# Out:
# ('2022_10_23_noise_reduced.csv',
#  ['/Users/rahulbrito/Documents/projects/infantvoice/data/Full_Readings/Noise_Reduced_1023/audio_16kz/BB043_BookReading_Reduced.wav',
#   '/Users/rahulbrito/Documents/projects/infantvoice/data/Full_Readings/Noise_Reduced_1023/audio_16kz/BB036_BookReading_Reduced.wav',
#   '/Users/rahulbrito/Documents/projects/infantvoice/data/Full_Readings/Noise_Reduced_1023/audio_16kz/BB047_BookReading_Reduced.wav',
#   '/Users/rahulbrito/Documents/projects/infantvoice/data/Full_Readings/Noise_Reduced_1023/audio_16kz/BB041_BookReading_Reduced.wav',
#   '/Users/rahulbrito/Documents/projects/infantvoice/data/Full_Readings/Noise_Reduced_1023/audio_16kz/BB046_BookReading_Reduced.wav',
#   '/Users/rahulbrito/Documents/projects/infantvoice/data/Full_Readings/Noise_Reduced_1023/audio_16kz/BB051_BookReading_Reduced.wav'])

# %%
pyannote_emb = ee.pyannote_extract_directory(all_files, diarized,emb_dir,save_name,window_type="sliding",save=True)
pyannote_emb
# Out:
# Processing/Users/rahulbrito/Documents/projects/infantvoice/data/Full_Readings/Noise_Reduced_1023/audio_16kz/BB051_BookReading_Reduced.wav
# Done
#               0          1           2          3          4           5  \
# 0    -53.002960  43.037251   22.262175  -6.488907  18.115126   10.440556
# 1    -62.321350  57.257393    6.307728  23.348244  83.326561   37.595287
# 2    -73.537498  37.322632   61.747086  39.009644  71.841110   10.079805
# 3    -45.638191  82.461220   47.501015   9.869690  24.392948 -133.673126
# 4    -49.042675  74.788910   50.560040  38.329834   0.997438  -77.854637
# ..          ...        ...         ...        ...        ...         ...
# 172   86.967995   8.746550   76.640839  74.639938 -34.247192  -36.602779
# 173  124.178535  40.368141   63.214882  29.161148 -43.641827  -72.928795
# 174  112.139565  13.066964  110.272316  59.235035 -46.912151    3.267069
# 175  106.879974   1.340430   99.530533  43.236759 -33.458153   -1.634304
# 176   57.947594  41.914349   50.522999   8.130493 -40.842121  -10.415643
#
#              6          7           8          9  ...         503        504  \
# 0   -16.703762  10.481370   -0.575003 -10.080816  ...  -35.364765 -61.425690
# 1    -0.787731 -58.585594  -10.693762   2.576586  ...   -1.687609 -43.507748
# 2     1.522079 -10.883791   -6.826080 -20.868519  ...    7.615963 -58.454430
# 3   -76.218918 -29.234159  -37.580013   5.617758  ...    9.131160 -32.381332
# 4   -26.053806 -29.994335  -57.548035   7.482622  ...   46.049515 -13.761900
# ..         ...        ...         ...        ...  ...         ...        ...
# 172  70.172073  11.313269  -27.948486  -3.843163  ...   -4.024303  58.206024
# 173  35.886547 -48.766392  -46.173122  -1.226389  ...  -13.677216  18.405090
# 174  34.597992 -37.189793  -82.026558 -27.805735  ... -118.154396   1.650517
# 175  19.879932  -7.034839  -93.242462  36.706882  ...  -52.892197 -25.049709
# 176   7.833282  20.518013 -124.104805  18.704311  ...   -5.758663 -59.648499
#
#            505        506        507        508         509        510  \
# 0    81.312958 -10.989422  -2.077003 -19.464863 -117.179428 -10.792107
# 1    88.050362  -7.388741 -33.223145  -9.142020  -95.024963 -88.441559
# 2    65.220093 -13.729263   1.225361  10.201973 -102.153496 -63.109264
# 3    -9.956151   3.870373   2.882145   6.979126  -69.512276 -37.404266
# 4     2.106606 -45.994137  -3.311981 -50.521679  -91.907661 -30.366264
# ..         ...        ...        ...        ...         ...        ...
# 172   7.225757  56.995079 -30.789059 -49.512138   -8.223751 -31.551880
# 173  52.109013  55.994331 -29.776062 -28.172552    9.322229 -47.306175
# 174  -9.451988 -14.087536 -28.361050  -5.376588  -26.737030 -58.612732
# 175   4.921539 -27.295013 -15.817932 -43.185051   13.406855 -26.453053
# 176  33.847477  -2.968948  -7.960629 -46.311195  -58.447075 -57.530857
#
#            511                    part_id
# 0     4.296803  BB043_BookReading_Reduced
# 1    -7.798065  BB043_BookReading_Reduced
# 2   -58.880775  BB043_BookReading_Reduced
# 3   -32.160839  BB043_BookReading_Reduced
# 4   -76.907372  BB043_BookReading_Reduced
# ..         ...                        ...
# 172  24.689877  BB051_BookReading_Reduced
# 173  -3.345567  BB051_BookReading_Reduced
# 174   0.416267  BB051_BookReading_Reduced
# 175  27.629055  BB051_BookReading_Reduced
# 176  17.357960  BB051_BookReading_Reduced
#
# [177 rows x 513 columns]

# %%
len(all_files)
# Out:
# 6

# %%
emb = pd.read_csv(os.path.join(emb_dir,save_name), index_col=0)
emb.shape
# Out:
# (177, 513)

# %%
emb.part_id.unique(), emb.part_id.unique().shape
# Out:
# (array(['BB043_BookReading_Reduced', 'BB036_BookReading_Reduced',
#         'BB047_BookReading_Reduced', 'BB041_BookReading_Reduced',
#         'BB046_BookReading_Reduced', 'BB051_BookReading_Reduced'],
#        dtype=object),
#  (6,))

# %%
emb
# Out:
#               0          1           2          3          4           5  \
# 0    -53.002960  43.037251   22.262175  -6.488907  18.115126   10.440556
# 1    -62.321350  57.257393    6.307728  23.348244  83.326561   37.595287
# 2    -73.537498  37.322632   61.747086  39.009644  71.841110   10.079805
# 3    -45.638191  82.461220   47.501015   9.869690  24.392948 -133.673126
# 4    -49.042675  74.788910   50.560040  38.329834   0.997438  -77.854637
# ..          ...        ...         ...        ...        ...         ...
# 172   86.967995   8.746550   76.640839  74.639938 -34.247192  -36.602779
# 173  124.178535  40.368141   63.214882  29.161148 -43.641827  -72.928795
# 174  112.139565  13.066964  110.272316  59.235035 -46.912151    3.267069
# 175  106.879974   1.340430   99.530533  43.236759 -33.458153   -1.634304
# 176   57.947594  41.914349   50.522999   8.130493 -40.842121  -10.415643
#
#              6          7           8          9  ...         503        504  \
# 0   -16.703762  10.481370   -0.575003 -10.080816  ...  -35.364765 -61.425690
# 1    -0.787731 -58.585594  -10.693762   2.576586  ...   -1.687609 -43.507748
# 2     1.522079 -10.883791   -6.826080 -20.868519  ...    7.615963 -58.454430
# 3   -76.218918 -29.234159  -37.580013   5.617758  ...    9.131160 -32.381332
# 4   -26.053806 -29.994335  -57.548035   7.482622  ...   46.049515 -13.761900
# ..         ...        ...         ...        ...  ...         ...        ...
# 172  70.172073  11.313269  -27.948486  -3.843163  ...   -4.024303  58.206024
# 173  35.886547 -48.766392  -46.173122  -1.226389  ...  -13.677216  18.405090
# 174  34.597992 -37.189793  -82.026558 -27.805735  ... -118.154396   1.650517
# 175  19.879932  -7.034839  -93.242462  36.706882  ...  -52.892197 -25.049709
# 176   7.833282  20.518013 -124.104805  18.704311  ...   -5.758663 -59.648499
#
#            505        506        507        508         509        510  \
# 0    81.312958 -10.989422  -2.077003 -19.464863 -117.179428 -10.792107
# 1    88.050362  -7.388741 -33.223145  -9.142020  -95.024963 -88.441559
# 2    65.220093 -13.729263   1.225361  10.201973 -102.153496 -63.109264
# 3    -9.956151   3.870373   2.882145   6.979126  -69.512276 -37.404266
# 4     2.106606 -45.994137  -3.311981 -50.521679  -91.907661 -30.366264
# ..         ...        ...        ...        ...         ...        ...
# 172   7.225757  56.995079 -30.789059 -49.512138   -8.223751 -31.551880
# 173  52.109013  55.994331 -29.776062 -28.172552    9.322229 -47.306175
# 174  -9.451988 -14.087536 -28.361050  -5.376588  -26.737030 -58.612732
# 175   4.921539 -27.295013 -15.817932 -43.185051   13.406855 -26.453053
# 176  33.847477  -2.968948  -7.960629 -46.311195  -58.447075 -57.530857
#
#            511                    part_id
# 0     4.296803  BB043_BookReading_Reduced
# 1    -7.798065  BB043_BookReading_Reduced
# 2   -58.880775  BB043_BookReading_Reduced
# 3   -32.160839  BB043_BookReading_Reduced
# 4   -76.907372  BB043_BookReading_Reduced
# ..         ...                        ...
# 172  24.689877  BB051_BookReading_Reduced
# 173  -3.345567  BB051_BookReading_Reduced
# 174   0.416267  BB051_BookReading_Reduced
# 175  27.629055  BB051_BookReading_Reduced
# 176  17.357960  BB051_BookReading_Reduced
#
# [177 rows x 513 columns]

# %%
os.path.join(emb_dir, save_name)
# Out:
# '/Users/rahulbrito/Documents/projects/infantvoice/data/embeddings/2022_10_23_noise_reduced.csv'
