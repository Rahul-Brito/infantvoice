# %%
import pandas as pd
import os

loc= '/Users/rahulbrito/Documents/projects/infantvoice/data/embeddings/'

files_emb_ami = [file for file in os.listdir(loc) if file.endswith('emb_ami.csv') & file.startswith('020422')]
files_emb_ami
# Out:
# ['020422_postpartum_moms_missed_emb_ami.csv',
#  '020422_postpartum_moms_emb_ami.csv']

# %%
emb_ami_first = pd.read_csv(os.path.join(loc,files_emb_ami[0]), index_col=0)
emb_ami_second = pd.read_csv(os.path.join(loc,files_emb_ami[1]), index_col=0)

# %%
emb_ami = pd.concat([emb_ami_second,emb_ami_first])
emb_ami
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.008272  0.016212 -0.021879  0.006547 -0.005488 -0.009625 -0.019599
# 1    0.007274  0.020259 -0.009325 -0.004239  0.013674  0.005985 -0.026527
# 2    0.002989  0.009281 -0.012662  0.000854  0.007706  0.031284 -0.005196
# 3   -0.000779  0.005044 -0.001138  0.009420 -0.001584  0.007116 -0.022268
# 4    0.009598  0.016656 -0.019442  0.010997 -0.001134  0.016841 -0.027624
# ..        ...       ...       ...       ...       ...       ...       ...
# 803 -0.014769 -0.025686  0.008285  0.033514  0.001241  0.009440 -0.012770
# 804 -0.005872 -0.019752 -0.009240  0.023423  0.004395  0.010698 -0.024872
# 805  0.002064  0.008560 -0.001302 -0.002330  0.003266  0.003700  0.016448
# 806 -0.004335  0.010551 -0.008720 -0.007525 -0.004252 -0.004014  0.007693
# 807 -0.001746  0.009517 -0.010910  0.004256 -0.001233 -0.000954  0.005323
#
#             7         8         9  ...       503       504       505  \
# ...

# %%
files_emb = [file for file in os.listdir(loc) if file.endswith('emb.csv') & file.startswith('020422')]
files_emb
# Out:
# ['020422_postpartum_moms_emb.csv', '020422_postpartum_moms_missed_emb.csv']

# %%
emb_first = pd.read_csv(os.path.join(loc,files_emb[0]), index_col=0)
emb_second = pd.read_csv(os.path.join(loc,files_emb[1]), index_col=0)

# %%
emb = pd.concat([emb_first, emb_second])
emb
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.171952 -0.090758 -0.265663 -0.010028 -0.016138  0.059564  0.513743
# 1   -0.214688 -0.177990 -0.136890  0.083366  0.041326  0.028714  0.537891
# 2   -0.618410  0.124517 -0.289026  0.011168  0.021796 -0.003787  0.089897
# 3   -0.612032  0.195473 -0.086323 -0.068080  0.049125 -0.053105 -0.128887
# 4   -0.521459  0.091132 -0.267745  0.001522 -0.107523  0.190905  0.000564
# ..        ...       ...       ...       ...       ...       ...       ...
# 233  0.062816 -0.329874 -0.120709 -0.412983 -0.063819  0.195769 -0.128237
# 234 -0.063985 -0.339374 -0.042894 -0.247621 -0.085302  0.265217  0.125682
# 235 -0.058125 -0.394210  0.035555 -0.339603  0.007150  0.307490  0.018324
# 236 -0.142515 -0.406153  0.150164 -0.562576 -0.099169  0.258588  0.054559
# 237 -0.120503  0.247129  0.396709  0.150472 -0.038368 -0.441988  0.206874
#
#             7         8         9  ...       503       504       505  \
# ...

# %%
files_emb_voxceleb = [file for file in os.listdir(loc) if file.endswith('emb_voxceleb.csv') & file.startswith('020422')]
files_emb_voxceleb
# Out:
# ['020422_postpartum_moms_missed_emb_voxceleb.csv',
#  '020422_postpartum_moms_emb_voxceleb.csv']

# %%
emb_vox_first = pd.read_csv(os.path.join(loc,files_emb_voxceleb[0]), index_col=0)
emb_vox_second = pd.read_csv(os.path.join(loc,files_emb_voxceleb[1]), index_col=0)

# %%
emb_vox_second
# Out:
#              0         1         2         3         4         5         6  \
# 0    -0.171952 -0.090758 -0.265663 -0.010028 -0.016138  0.059564  0.513743
# 1    -0.214688 -0.177990 -0.136890  0.083366  0.041326  0.028714  0.537891
# 2    -0.618410  0.124517 -0.289026  0.011168  0.021796 -0.003787  0.089897
# 3    -0.612032  0.195473 -0.086323 -0.068080  0.049125 -0.053105 -0.128887
# 4    -0.521459  0.091132 -0.267745  0.001522 -0.107523  0.190905  0.000564
# ...        ...       ...       ...       ...       ...       ...       ...
# 1474  0.473904 -0.092172  0.392526  0.106837  0.404739 -0.258119 -0.336828
# 1475  0.604839 -0.105145  0.342174  0.017456  0.301545 -0.171638 -0.234701
# 1476  0.485853 -0.237617  0.127132  0.027915  0.222662 -0.084863 -0.052841
# 1477  0.268996 -0.282207  0.068990 -0.038790  0.096356  0.017746 -0.040361
# 1478  0.411924 -0.164758  0.146990  0.047701  0.435030  0.227375 -0.161942
#
# ...
