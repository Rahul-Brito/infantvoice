# %%
toy = '/Users/rahulbrito/Documents/projects/infantvoice/data/Full_Readings/0300222_recordings_16khz/001.wav'
toy2 ='/Users/rahulbrito/Documents/projects/infantvoice/data/Full_Readings/0300222_recordings_16khz/002.wav'

# %%
from pyannote.audio import Inference
inference = Inference("pyannote/embedding", 
                      window="sliding",
                      duration=3.0, step=1.0)
embeddings = inference(toy)
# `embeddings` is a (N x D) pyannote.core.SlidingWindowFeature
# `embeddings[i]` is the embedding of the ith position of the 
# sliding window, i.e. from [i * step, i * step + duration].

# %%
import pandas as pd
pd.DataFrame([a for a in embeddings])
# Out:
#                                      0  \
# 0    [ 00:00:00.000 -->  00:00:03.000]
# 1    [ 00:00:01.000 -->  00:00:04.000]
# 2    [ 00:00:02.000 -->  00:00:05.000]
# 3    [ 00:00:03.000 -->  00:00:06.000]
# 4    [ 00:00:04.000 -->  00:00:07.000]
# ..                                 ...
# 469  [ 00:07:49.000 -->  00:07:52.000]
# 470  [ 00:07:50.000 -->  00:07:53.000]
# 471  [ 00:07:51.000 -->  00:07:54.000]
# 472  [ 00:07:52.000 -->  00:07:55.000]
# 473  [ 00:07:53.000 -->  00:07:56.000]
#
#                                                      1
# 0    [-53.40696, -2.1173239, -44.76246, -27.198696,...
# 1    [34.056988, -85.477684, 31.266687, -61.084797,...
# 2    [93.55968, -35.94081, -38.016197, -50.366577, ...
# 3    [57.44062, -83.02393, -52.401985, 0.83237076, ...
# 4    [51.459972, -79.12097, -72.33758, 15.441002, 1...
# ..                                                 ...
# 469  [-42.70327, 1.8469644, -17.827286, -8.57255, -...
# 470  [-35.5779, -1.8786111, -45.91268, -30.667583, ...
# 471  [-17.6541, -5.232683, -17.006723, -46.43578, 1...
# 472  [-14.01729, 46.908363, -2.0050392, -31.156864,...
# 473  [38.544662, 111.716385, 52.60743, 36.246693, 2...
#
# [474 rows x 2 columns]

# %%
loc = '/Users/rahulbrito/Documents/projects/infantvoice/data/embeddings/020422_postpartum_moms_emb_voxceleb.csv'
pyv1 = pd.read_csv(loc, index_col=0)

# %%
pyv1
# Out:
#              0         1         2         3         4         5         6  \
# 0    -0.171952 -0.090758 -0.265663 -0.010028 -0.016138  0.059564  0.513743
# 1    -0.214688 -0.177990 -0.136890  0.083366  0.041326  0.028714  0.537891
# 2    -0.618410  0.124517 -0.289026  0.011168  0.021796 -0.003787  0.089897
# 3    -0.612032  0.195473 -0.086323 -0.068080  0.049125 -0.053105 -0.128887
# 4    -0.521459  0.091132 -0.267745  0.001522 -0.107523  0.190905  0.000564
# ...        ...       ...       ...       ...       ...       ...       ...
# 1474  0.473904 -0.092172  0.392526  0.106837  0.404739 -0.258119 -0.336828
# 1475  0.604839 -0.105145  0.342174  0.017456  0.301545 -0.171638 -0.234701
# 1476  0.485853 -0.237617  0.127132  0.027915  0.222662 -0.084863 -0.052841
# 1477  0.268996 -0.282207  0.068990 -0.038790  0.096356  0.017746 -0.040361
# 1478  0.411924 -0.164758  0.146990  0.047701  0.435030  0.227375 -0.161942
#
#              7         8         9  ...       503       504       505  \
# 0    -0.131574  0.290008 -0.408053  ...  0.202271 -0.441385  0.287715
# 1    -0.003605  0.266139 -0.501707  ...  0.182709 -0.380817  0.185325
# 2    -0.225240  0.254082 -0.761027  ... -0.118381 -0.655614 -0.044049
# 3    -0.257071  0.540098 -0.796341  ... -0.279127 -0.485830 -0.112884
# 4    -0.199527  0.095490 -0.756954  ... -0.331826 -0.493360 -0.233281
# ...        ...       ...       ...  ...       ...       ...       ...
# 1474 -0.040389 -0.034079 -0.166052  ... -0.149241 -0.045204 -0.557780
# 1475 -0.015413 -0.013035 -0.280594  ... -0.186135 -0.015748 -0.534130
# 1476  0.102810 -0.033161 -0.346510  ... -0.182264 -0.106386 -0.537408
# 1477  0.081036  0.033564 -0.379094  ... -0.146928 -0.130111 -0.444524
# 1478 -0.060359 -0.022440 -0.371253  ... -0.080424  0.049533 -0.664217
#
#            506       507       508       509       510       511  part_id
# 0     0.577549 -0.135824  0.040210 -0.119001 -0.254891 -0.197471       14
# 1     0.610559 -0.169842 -0.025926 -0.198027 -0.246766 -0.201128       14
# 2     0.330091  0.066981 -0.152289  0.035468 -0.378672 -0.155690       14
# 3     0.315839  0.066025 -0.114535  0.106349 -0.387214 -0.162670       14
# 4    -0.187931 -0.008210 -0.279751  0.086088 -0.234080 -0.239553       14
# ...        ...       ...       ...       ...       ...       ...      ...
# 1474 -0.333925  0.077385 -0.234948 -0.060622 -0.054222  0.137274       19
# 1475 -0.467488 -0.033189 -0.357069 -0.125971 -0.011477  0.044014       19
# 1476 -0.558214 -0.040613 -0.508625 -0.146780  0.061051  0.056956       19
# 1477 -0.519786 -0.163223 -0.522427 -0.263253 -0.078726 -0.085248       19
# 1478 -0.583451 -0.132006 -0.578623 -0.416497 -0.056870  0.087913       19
#
# [1479 rows x 513 columns]

# %%
import torchaudio
from speechbrain.pretrained import EncoderClassifier
classifier = EncoderClassifier.from_hparams(source="speechbrain/spkrec-ecapa-voxceleb",window="sliding",
                      duration=3.0, step=1.0)
signal, fs =torchaudio.load(toy)
emb = classifier.encode_batch(signal)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/fg/c6b2vcrx7wd1530hgxsj7z7w0000gn/T/ipykernel_32591/942479066.py in <module>
#       1 import torchaudio
#       2 from speechbrain.pretrained import EncoderClassifier
# ----> 3 classifier = EncoderClassifier.from_hparams(source="speechbrain/spkrec-ecapa-voxceleb",window="sliding",
#       4                       duration=3.0, step=1.0)
#       5 signal, fs =torchaudio.load(toy)
#
# ~/Documents/projects/infantvoice/src/speechbrain/speechbrain/pretrained/interfaces.py in from_hparams(cls, source, hparams_file, pymodule_file, overrides, savedir, use_auth_token, **kwargs)
#     362
#     363         # Now return the system
# --> 364         return cls(hparams["modules"], hparams, **kwargs)
#     365
#     366
#
# ~/Documents/projects/infantvoice/src/speechbrain/speechbrain/pretrained/interfaces.py in __init__(self, *args, **kwargs)
#     758
#     759     def __init__(self, *args, **kwargs):
# --> 760         super().__init__(*args, **kwargs)
#     761
#     762     def encode_batch(self, wavs, wav_lens=None, normalize=False):
#
# TypeError: __init__() got an unexpected keyword argument 'window'

# %%
emb
# Out:
# tensor([[[  2.3898,  20.0854,   5.6097,  -9.6768, -28.4067,  -8.7293,   2.9043,
#             7.6407, -18.5940,   2.2506, -34.1210,   0.2741,   6.9153, -10.1204,
#           -12.0306, -29.8530,  18.3538,  14.3152, -14.8401,   7.3100,  19.4661,
#            42.4019,  22.3650,  16.1681,  -4.7052,  -0.4951,   4.0342,  -2.9181,
#           -29.9277,   0.4488,   3.7865,   9.2714, -10.0736,  -9.7215, -10.5303,
#            -2.5727,   9.8959,  -6.8613, -16.8972,  27.2789, -18.7742,  -4.5883,
#             8.4775,   2.4293,   1.4861,   8.6430, -33.2118, -34.6032,  -3.1069,
#           -25.4073,  20.8373,  26.0492, -24.6707,   1.0971,  25.0304, -12.4288,
#             0.2809, -17.8488, -18.3381,   8.9239,  33.8517,  23.5397, -46.7325,
#           -14.8639,  23.1350,  26.2555,  17.7878,  23.1908,  11.0924, -41.5638,
#           -29.4357,  11.7076,  -7.0330, -14.3532, -26.3602,  -3.6142, -16.4368,
#            -5.5519,   4.4380,  37.9710, -22.6280,  15.3411, -13.2032,  15.9275,
#            41.6001,   5.1720, -38.7507, -36.9759, -22.2312, -50.2596, -17.0741,
#             3.1272,  -0.6467,  -0.2676, -19.1324,  16.9935,  -9.7188,  -2.8121,
#           -12.3212,  27.4642, -33.6406, -24.0350,  28.2985,  -4.6620,  14.1379,
#            -1.1670,   1.0883, -29.5332, -11.2673, -24.0734, -37.7888, -33.6432,
#            14.8118,  -3.9356,  -6.2235,  27.4923,   5.1126,  -0.9643,  33.2752,
#           -28.8194,   5.0233,   0.0811,  20.2270,  27.3054,  20.9269,   3.6530,
#            -0.2021,  -5.0301, -30.6054, -30.3633, -13.2052,   5.2647,   7.0749,
#            20.7355,  13.5344,   5.2728,  23.0419, -12.1939, -41.6933,   2.8926,
#            23.0123, -26.8705,   9.5593,  27.6619,  -3.8419, -11.8831,  21.3115,
#             9.7749,  -6.3351,  12.5212, -21.8542,   4.2753,  21.1805,  19.2640,
#           -19.6863, -27.9364,  -8.8547,   5.4499,  15.7237, -12.4287, -22.2348,
#            33.8269,  -8.6889,   7.6972, -10.8935, -11.7360,  18.3705, -14.2686,
#           -21.4590,  -5.2566,   5.5767, -31.3256, -33.5919,  13.9558,   6.5210,
#            -5.7368, -17.5223, -16.6856, -10.7189, -20.8213,  29.7458,  13.4971,
#           -23.0934,  17.5260,   9.3977, -11.7012, -14.5433,  23.1174,  -9.0311,
#            -9.6839, -11.8179, -35.2508]]])

# %%
from speechbrain.pretrained import SpeakerRecognition
verification = SpeakerRecognition.from_hparams(source="speechbrain/spkrec-ecapa-voxceleb", savedir="pretrained_models/spkrec-ecapa-voxceleb")
score, prediction = verification.verify_files(toy, toy2)

# %%
score, prediction
# Out:
# (tensor([0.7122]), tensor([True]))
